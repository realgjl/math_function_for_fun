# %%
import matplotlib.pyplot as plt

# %%
def fibonacci(index):
    if index >= 3:
        index_list = [1,2]
        fibo_list = [1,1]
        fibo1 = 1
        fibo2 = 1
        i = 3
        while i <= index:
            fib_next = fibo1 + fibo2
            index_list.append(i)
            fibo_list.append(fib_next)
            i += 1
            fibo1 = fibo2
            fibo2 = fib_next
        # return(index_list, fibo_list)
        fig = plt.figure(figsize=(15,7))
        plt.plot(index_list, fibo_list)
    else:
        print("at least first three of fibonacci number")

# %%
# x, fibo_value = fibonacci(10)
# print(x)
# print(fibo_value)
# fig = plt.figure(figsize=(15,7))
# plt.plot(x, fibo_value)

# %%
fibonacci(3)

# %%
fibonacci(10)

# %%
fibonacci(20)

# %%
fibonacci(50)

# %%
fibonacci(70)

# %%
fibonacci(100)

# %%
fibonacci(150)

# %%
fibonacci(200)

# %%
fibonacci(500)

# %%
fibonacci(1000)

# %%
fibonacci(2000)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-14-23f91187a8b4> in <module>
# ----> 1 fibonacci(2000)
#
# <ipython-input-2-78d737234736> in fibonacci(index)
#      15         # return(index_list, fibo_list)
#      16         fig = plt.figure(figsize=(15,7))
# ---> 17         plt.plot(index_list, fibo_list)
#      18     else:
#      19         print("at least first three of fibonacci number")
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %%
fibonacci(1500)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-15-a96319b9f541> in <module>
# ----> 1 fibonacci(1500)
#
# <ipython-input-2-78d737234736> in fibonacci(index)
#      15         # return(index_list, fibo_list)
#      16         fig = plt.figure(figsize=(15,7))
# ---> 17         plt.plot(index_list, fibo_list)
#      18     else:
#      19         print("at least first three of fibonacci number")
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %%
fibonacci(1300)
